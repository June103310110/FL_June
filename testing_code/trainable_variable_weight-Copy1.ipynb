# %%
import tensorflow as tf
import tensorflow.keras as keras 
 
class CustomModel(keras.Model):
    def train_step(self, data):
        # Unpack the data. Its structure depends on your model and
        # on what you pass to `fit()`.
        x, y = data

        with tf.GradientTape() as tape:
            y_pred = self(x, training=True)  # Forward pass
            # Compute the loss value
            # (the loss function is configured in `compile()`)
            loss = self.compiled_loss(y, y_pred, regularization_losses=self.losses)

        # Compute gradients
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        # Update metrics (includes the metric that tracks the loss)
        self.compiled_metrics.update_state(y, y_pred)
        # Return a dict mapping metric names to current value
        
        return {m.name: m.result() for m in self.metrics}

# %%
import resource
def using(point=""):
    usage=resource.getrusage(resource.RUSAGE_SELF)
    return '''%s: usertime=%s systime=%s mem=%s mb
           '''%(point,usage[0],usage[1],
                usage[2]/1024.0 )

# %%
import numpy as np

# Construct and compile an instance of CustomModel
inputs = keras.Input(shape=(32,))
outputs = keras.layers.Dense(100)(inputs)

model = CustomModel(inputs, outputs)
model.compile(optimizer="adam", loss="mse", metrics=["mae"])
x = np.random.random((1000, 32))
y = np.random.random((1000, 1))

for i in range(int(1e5)):

    model.fit(x, y, epochs=int(1e1), verbose=False)
    print(using("after"))
# Out:
# after: usertime=441.986728 systime=57.024734 mem=1430.1171875 mb
#
# after: usertime=442.473599 systime=57.126383 mem=1430.1328125 mb
#
# after: usertime=442.98091 systime=57.205181 mem=1430.1328125 mb
#
# after: usertime=443.513417 systime=57.259892 mem=1430.1328125 mb
#
# after: usertime=444.040051 systime=57.32454 mem=1430.1328125 mb
#
# after: usertime=444.563174 systime=57.389004 mem=1430.265625 mb
#
# after: usertime=445.102599 systime=57.437083 mem=1430.265625 mb
#
# after: usertime=445.629428 systime=57.49727 mem=1430.265625 mb
#
# after: usertime=446.143298 systime=57.58127 mem=1430.453125 mb
#
# after: usertime=446.63779 systime=57.676899 mem=1430.453125 mb
#
# after: usertime=447.137084 systime=57.763376 mem=1430.453125 mb
#
# after: usertime=447.648496 systime=57.839668 mem=1430.453125 mb
#
# after: usertime=448.165233 systime=57.913475 mem=1430.453125 mb
#
# after: usertime=448.698358 systime=57.965756999999996 mem=1430.453125 mb
#
# after: usertime=449.219467 systime=58.034057 mem=1430.453125 mb
#
# after: usertime=449.725528 systime=58.117179 mem=1430.453125 mb
#
# after: usertime=450.251551 systime=58.18386 mem=1430.453125 mb
#
# after: usertime=450.78549 systime=58.237581 mem=1430.453125 mb
#
# after: usertime=451.313269 systime=58.294579 mem=1430.453125 mb
#
# after: usertime=451.829649 systime=58.369926 mem=1430.453125 mb
#
# after: usertime=452.348653 systime=58.438737 mem=1430.453125 mb
#
# after: usertime=452.85412 systime=58.521389 mem=1430.453125 mb
#
# after: usertime=453.381095 systime=58.58318 mem=1430.453125 mb
#
# after: usertime=453.907973 systime=58.647994 mem=1430.4765625 mb
#
# after: usertime=454.449526 systime=58.696609 mem=1430.4765625 mb
#
# after: usertime=454.985826 systime=58.746269 mem=1430.4765625 mb
#
# after: usertime=455.501721 systime=58.817323 mem=1430.4765625 mb
#
# after: usertime=456.013639 systime=58.895128 mem=1430.4765625 mb
#
# after: usertime=456.553848 systime=58.940672 mem=1430.4765625 mb
#
# after: usertime=457.088245 systime=58.991538 mem=1430.4765625 mb
#
# after: usertime=457.60995 systime=59.059912 mem=1430.4765625 mb
#
# after: usertime=458.145819 systime=59.116778 mem=1430.4765625 mb
#
# after: usertime=458.665702 systime=59.192574 mem=1430.4765625 mb
#
# after: usertime=459.200899 systime=59.246711 mem=1430.4765625 mb
#
# after: usertime=459.704701 systime=59.330071 mem=1430.4765625 mb
#
# after: usertime=460.238607 systime=59.384702 mem=1430.4765625 mb
#
# after: usertime=460.768699 systime=59.442801 mem=1430.4765625 mb
#
# after: usertime=461.294906 systime=59.506474 mem=1430.4765625 mb
#
# after: usertime=461.821501 systime=59.570327 mem=1430.4765625 mb
#
# after: usertime=462.37451 systime=59.611311 mem=1430.4765625 mb
#
# after: usertime=462.904182 systime=59.676087 mem=1430.4765625 mb
#
# after: usertime=463.416563 systime=59.748933 mem=1430.4765625 mb
#
# after: usertime=463.919589 systime=59.832329 mem=1430.4765625 mb
#
# after: usertime=464.444063 systime=59.89802 mem=1430.4765625 mb
#
# after: usertime=464.981552 systime=59.951391 mem=1430.4765625 mb
#
# after: usertime=465.494582 systime=60.025648 mem=1430.4765625 mb
#
# after: usertime=466.00554 systime=60.099896 mem=1430.4765625 mb
#
# after: usertime=466.528621 systime=60.163693 mem=1430.4765625 mb
#
# after: usertime=467.060046 systime=60.223416 mem=1430.4765625 mb
#
# after: usertime=467.606883 systime=60.265583 mem=1430.4765625 mb
#
# after: usertime=468.123905 systime=60.341538 mem=1430.4765625 mb
#
# after: usertime=468.63399 systime=60.422676 mem=1430.48828125 mb
#
# after: usertime=469.136786 systime=60.508553 mem=1430.48828125 mb
#
# after: usertime=469.642383 systime=60.588452 mem=1430.4921875 mb
#
# after: usertime=470.185395 systime=60.634351 mem=1430.4921875 mb
#
# after: usertime=470.697519 systime=60.708749 mem=1430.4921875 mb
#
# after: usertime=471.225408 systime=60.774223 mem=1430.4921875 mb
#
# after: usertime=471.759366 systime=60.830178 mem=1430.4921875 mb
#
# after: usertime=472.281392 systime=60.895823 mem=1430.4921875 mb
#
# after: usertime=472.777568 systime=60.986521 mem=1430.4921875 mb
#
# after: usertime=473.298368 systime=61.055174 mem=1430.4921875 mb
#
# after: usertime=473.820447 systime=61.121351 mem=1430.51171875 mb
#
# after: usertime=474.332542 systime=61.192447 mem=1430.51171875 mb
#
# after: usertime=474.866135 systime=61.247302 mem=1430.51171875 mb
#
# after: usertime=475.396938 systime=61.309058 mem=1430.51171875 mb
#
# after: usertime=475.905015 systime=61.389933 mem=1430.51171875 mb
#
# after: usertime=476.428592 systime=61.455776 mem=1430.51171875 mb
#
# after: usertime=476.958146 systime=61.517372 mem=1430.5859375 mb
#
# after: usertime=477.485708 systime=61.576072 mem=1430.5859375 mb
#
# after: usertime=477.997406 systime=61.654245 mem=1430.5859375 mb
#
# after: usertime=478.520174 systime=61.719587 mem=1430.5859375 mb
#
# after: usertime=479.058255 systime=61.767766 mem=1430.5859375 mb
#
# after: usertime=479.608321 systime=61.811946 mem=1430.5859375 mb
#
# after: usertime=480.13645 systime=61.871376 mem=1430.5859375 mb
#
# after: usertime=480.675852 systime=61.919329 mem=1430.5859375 mb
#
# after: usertime=481.198529 systime=61.983729 mem=1430.5859375 mb
#
# after: usertime=481.729907 systime=62.040414 mem=1430.5859375 mb
#
# after: usertime=482.205097 systime=62.15137 mem=1430.5859375 mb
#
# after: usertime=482.723141 systime=62.22125 mem=1430.5859375 mb
#
# after: usertime=483.222568 systime=62.308792 mem=1430.5859375 mb
#
# after: usertime=483.765228 systime=62.358747 mem=1430.5859375 mb
#
# after: usertime=484.315109 systime=62.395897 mem=1430.5859375 mb
#
# after: usertime=484.820667 systime=62.478957 mem=1430.5859375 mb
#
# after: usertime=485.329397 systime=62.555822 mem=1430.5859375 mb
#
# after: usertime=485.838171 systime=62.632292 mem=1430.5859375 mb
#
# after: usertime=486.371432 systime=62.685781 mem=1430.5859375 mb
#
# after: usertime=486.903098 systime=62.743156 mem=1430.5859375 mb
#
# after: usertime=487.407191 systime=62.827211 mem=1430.5859375 mb
#
# after: usertime=487.963704 systime=62.866665 mem=1430.5859375 mb
#
# after: usertime=488.476739 systime=62.944087 mem=1430.5859375 mb
#
# after: usertime=488.991539 systime=63.019227 mem=1430.5859375 mb
#
# after: usertime=489.524334 systime=63.071344 mem=1430.5859375 mb
#
# after: usertime=490.060395 systime=63.123482 mem=1430.5859375 mb
#
# after: usertime=490.571917 systime=63.19767 mem=1430.5859375 mb
#
# after: usertime=491.102261 systime=63.258438 mem=1430.5859375 mb
#
# after: usertime=491.642496 systime=63.308074 mem=1430.5859375 mb
#
# after: usertime=492.178988 systime=63.365942 mem=1430.68359375 mb
#
# after: usertime=492.724059 systime=63.409351 mem=1430.68359375 mb
#
# after: usertime=493.224155 systime=63.496333 mem=1430.68359375 mb
#
# after: usertime=493.735374 systime=63.572061 mem=1430.68359375 mb
#
# after: usertime=494.253678 systime=63.642379 mem=1430.68359375 mb
#
# after: usertime=494.740526 systime=63.742038 mem=1430.68359375 mb
#
# after: usertime=495.254104 systime=63.815034 mem=1430.68359375 mb
#
# after: usertime=495.793006 systime=63.863849 mem=1430.68359375 mb
#
# after: usertime=496.330271 systime=63.92247 mem=1430.73828125 mb
#
# after: usertime=496.86293 systime=63.978792 mem=1430.73828125 mb
#
# after: usertime=497.373808 systime=64.053423 mem=1430.73828125 mb
#
# after: usertime=497.896439 systime=64.119274 mem=1430.73828125 mb
#
# after: usertime=498.431837 systime=64.169748 mem=1430.73828125 mb
#
# after: usertime=498.927168 systime=64.264825 mem=1430.73828125 mb
#
# after: usertime=499.439289 systime=64.340545 mem=1430.73828125 mb
#
# after: usertime=499.955754 systime=64.410749 mem=1430.73828125 mb
#
# after: usertime=500.498443 systime=64.460706 mem=1430.73828125 mb
#
# after: usertime=501.020114 systime=64.529472 mem=1430.73828125 mb
#
# after: usertime=501.543213 systime=64.591818 mem=1430.73828125 mb
#
# after: usertime=502.077679 systime=64.652993 mem=1430.77734375 mb
#
# after: usertime=502.605068 systime=64.71273 mem=1430.77734375 mb
#
# after: usertime=503.118442 systime=64.787558 mem=1430.77734375 mb
#
# after: usertime=503.633982 systime=64.858573 mem=1430.77734375 mb
#
# after: usertime=504.151188 systime=64.927291 mem=1430.77734375 mb
#
# after: usertime=504.66852 systime=65.004458 mem=1430.77734375 mb
#
# after: usertime=505.199186 systime=65.065546 mem=1430.77734375 mb
#
# after: usertime=505.720978 systime=65.132622 mem=1430.77734375 mb
#
# after: usertime=506.253057 systime=65.187012 mem=1430.77734375 mb
#
# after: usertime=506.780372 systime=65.24674 mem=1430.77734375 mb
#
# after: usertime=507.31296 systime=65.302002 mem=1430.77734375 mb
#
# after: usertime=507.852623 systime=65.349706 mem=1430.77734375 mb
#
# after: usertime=508.404985 systime=65.384945 mem=1430.77734375 mb
#
# after: usertime=508.946076 systime=65.441302 mem=1430.77734375 mb
#
# after: usertime=509.466532 systime=65.509913 mem=1430.77734375 mb
#
# after: usertime=509.998944 systime=65.563577 mem=1430.77734375 mb
#
# after: usertime=510.534437 systime=65.61869 mem=1430.77734375 mb
#
# after: usertime=511.041032 systime=65.699898 mem=1430.77734375 mb
#
# after: usertime=511.577853 systime=65.751616 mem=1430.77734375 mb
#
# after: usertime=512.108856 systime=65.809193 mem=1430.77734375 mb
#
# after: usertime=512.639678 systime=65.8654 mem=1430.77734375 mb
#
# after: usertime=513.155092 systime=65.943238 mem=1430.77734375 mb
#
# after: usertime=513.691142 systime=65.998835 mem=1430.77734375 mb
#
# after: usertime=514.225974 systime=66.056607 mem=1430.77734375 mb
#
# after: usertime=514.728894 systime=66.142487 mem=1430.77734375 mb
#
# after: usertime=515.238788 systime=66.218976 mem=1430.77734375 mb
#
# after: usertime=515.751449 systime=66.29278 mem=1430.77734375 mb
#
# after: usertime=516.283078 systime=66.354003 mem=1430.77734375 mb
#
# after: usertime=516.828445 systime=66.396011 mem=1430.77734375 mb
#
# after: usertime=517.370013 systime=66.447929 mem=1430.77734375 mb
#
# after: usertime=517.906296 systime=66.50052 mem=1430.77734375 mb
#
# after: usertime=518.395795 systime=66.600624 mem=1430.77734375 mb
#
# after: usertime=518.935061 systime=66.650145 mem=1430.77734375 mb
#
# after: usertime=519.470638 systime=66.7079 mem=1430.77734375 mb
#
# after: usertime=519.972491 systime=66.795103 mem=1430.77734375 mb
#
# after: usertime=520.49285 systime=66.865166 mem=1430.77734375 mb
#
# after: usertime=521.028172 systime=66.922363 mem=1430.77734375 mb
#
# after: usertime=521.566085 systime=66.981995 mem=1430.78125 mb
#
# after: usertime=522.083512 systime=67.054834 mem=1430.78125 mb
#
# after: usertime=522.625064 systime=67.105174 mem=1430.78125 mb
#
# after: usertime=523.134242 systime=67.185661 mem=1430.78125 mb
#
# after: usertime=523.675208 systime=67.232472 mem=1430.78125 mb
#
# after: usertime=524.188714 systime=67.30796 mem=1430.78125 mb
#
# after: usertime=524.712701 systime=67.369368 mem=1430.78125 mb
#
# after: usertime=525.213849 systime=67.455431 mem=1430.78125 mb
#
# after: usertime=525.747417 systime=67.515857 mem=1430.78125 mb
#
# after: usertime=526.262997 systime=67.592024 mem=1430.78125 mb
#
# after: usertime=526.782818 systime=67.659615 mem=1430.78125 mb
#
# after: usertime=527.31232 systime=67.716892 mem=1430.78125 mb
#
# after: usertime=527.860217 systime=67.759758 mem=1430.78125 mb
#
# after: usertime=528.386777 systime=67.822548 mem=1430.78125 mb
#
# after: usertime=528.929318 systime=67.868294 mem=1430.78125 mb
#
# after: usertime=529.451891 systime=67.933612 mem=1430.78125 mb
#
# after: usertime=529.976152 systime=68.003346 mem=1430.78125 mb
#
# after: usertime=530.509032 systime=68.061698 mem=1430.78125 mb
#
# after: usertime=531.043796 systime=68.11526 mem=1430.78125 mb
#
# after: usertime=531.56289 systime=68.185272 mem=1430.78125 mb
#
# after: usertime=532.121272 systime=68.214489 mem=1430.78125 mb
#
# after: usertime=532.66347 systime=68.260301 mem=1430.78125 mb
#
# after: usertime=533.164044 systime=68.346814 mem=1430.78125 mb
#
# after: usertime=533.722435 systime=68.378241 mem=1430.78125 mb
#
# after: usertime=534.253424 systime=68.441072 mem=1430.78125 mb
#
# after: usertime=534.777409 systime=68.508144 mem=1430.78125 mb
#
# after: usertime=535.27165 systime=68.604543 mem=1430.78125 mb
#
# after: usertime=535.810028 systime=68.65306 mem=1430.78125 mb
#
# after: usertime=536.354423 systime=68.695862 mem=1430.78125 mb
#
# after: usertime=536.86315 systime=68.773669 mem=1430.78125 mb
#
# after: usertime=537.403582 systime=68.8223 mem=1430.78125 mb
#
# after: usertime=537.921121 systime=68.890117 mem=1430.78125 mb
#
# after: usertime=538.465153 systime=68.941727 mem=1430.78125 mb
#
# after: usertime=539.028063 systime=68.967655 mem=1430.78125 mb
#
# after: usertime=539.566128 systime=69.017981 mem=1430.78125 mb
#
# after: usertime=540.081606 systime=69.091093 mem=1430.78125 mb
#
# after: usertime=540.608423 systime=69.152771 mem=1430.78125 mb
#
# after: usertime=541.117092 systime=69.23162 mem=1430.78125 mb
#
# after: usertime=541.646867 systime=69.290207 mem=1430.78125 mb
#
# after: usertime=542.178664 systime=69.344868 mem=1430.78125 mb
#
# after: usertime=542.717836 systime=69.40109 mem=1430.78125 mb
#
# after: usertime=543.235303 systime=69.470891 mem=1430.78125 mb
#
# after: usertime=543.745787 systime=69.547881 mem=1430.78125 mb
#
# after: usertime=544.270945 systime=69.61006 mem=1430.78125 mb
#
# after: usertime=544.791243 systime=69.67604 mem=1430.78125 mb
#
# after: usertime=545.291162 systime=69.760996 mem=1430.78125 mb
#
# after: usertime=545.815517 systime=69.830109 mem=1430.78125 mb
#
# after: usertime=546.326366 systime=69.905767 mem=1430.78125 mb
#
# after: usertime=546.862415 systime=69.966106 mem=1430.78125 mb
#
# after: usertime=547.36365 systime=70.055319 mem=1430.78125 mb
#
# after: usertime=547.880646 systime=70.126531 mem=1430.78125 mb
#
# after: usertime=548.416027 systime=70.182697 mem=1430.78125 mb
#
# after: usertime=548.922259 systime=70.265843 mem=1430.78125 mb
#
# after: usertime=549.429804 systime=70.344218 mem=1430.78125 mb
#
# after: usertime=549.957536 systime=70.404116 mem=1430.78125 mb
#
# after: usertime=550.4736 systime=70.475632 mem=1430.78125 mb
#
# after: usertime=551.002149 systime=70.546852 mem=1430.78125 mb
#
# after: usertime=551.555089 systime=70.582208 mem=1430.78125 mb
#
# after: usertime=552.054443 systime=70.667711 mem=1430.78125 mb
#
# after: usertime=552.600634 systime=70.707434 mem=1430.78125 mb
#
# after: usertime=553.139614 systime=70.757452 mem=1430.78125 mb
#
# after: usertime=553.673704 systime=70.812073 mem=1430.78125 mb
#
# after: usertime=554.190328 systime=70.884286 mem=1430.78125 mb
#
# after: usertime=554.720119 systime=70.943825 mem=1430.78125 mb
#
# after: usertime=555.236207 systime=71.019631 mem=1430.78125 mb
#
# after: usertime=555.780651 systime=71.065546 mem=1430.87109375 mb
#
# after: usertime=556.318624 systime=71.11562 mem=1430.87109375 mb
#
# after: usertime=556.826395 systime=71.193928 mem=1430.87109375 mb
#
# after: usertime=557.357101 systime=71.257767 mem=1430.87109375 mb
#
# after: usertime=557.877413 systime=71.32627 mem=1430.87109375 mb
#
# after: usertime=558.426463 systime=71.363647 mem=1430.87109375 mb
#
# after: usertime=558.946289 systime=71.431658 mem=1430.87109375 mb
#
# after: usertime=559.480489 systime=71.494375 mem=1431.48828125 mb
#
# after: usertime=560.138315 systime=71.589925 mem=1431.546875 mb
#
# after: usertime=560.684794 systime=71.635765 mem=1431.546875 mb
#
# after: usertime=561.204152 systime=71.70633 mem=1431.546875 mb
#
# after: usertime=561.730747 systime=71.770596 mem=1431.546875 mb
#
# after: usertime=562.272715 systime=71.819515 mem=1431.546875 mb
#
# after: usertime=562.806103 systime=71.882039 mem=1431.546875 mb
#
# after: usertime=563.337191 systime=71.942356 mem=1431.546875 mb
#
# after: usertime=563.874236 systime=71.99369 mem=1431.546875 mb
#
# after: usertime=564.394296 systime=72.06269 mem=1431.546875 mb
#
# after: usertime=564.910434 systime=72.137454 mem=1431.546875 mb
#
# after: usertime=565.425486 systime=72.213991 mem=1431.546875 mb
#
# after: usertime=565.958687 systime=72.271967 mem=1431.546875 mb
#
# after: usertime=566.499188 systime=72.319668 mem=1431.546875 mb
#
# after: usertime=567.01816 systime=72.395562 mem=1431.546875 mb
#
# after: usertime=567.558742 systime=72.44674 mem=1431.546875 mb
#
# after: usertime=568.070983 systime=72.522657 mem=1431.546875 mb
#
# after: usertime=568.615009 systime=72.567578 mem=1431.546875 mb
#
# after: usertime=569.17943 systime=72.592659 mem=1431.546875 mb
#
# after: usertime=569.711424 systime=72.652484 mem=1431.546875 mb
#
# after: usertime=570.245171 systime=72.715059 mem=1431.5703125 mb
#
# after: usertime=570.774683 systime=72.775173 mem=1431.5703125 mb
#
# after: usertime=571.289994 systime=72.85644 mem=1431.5703125 mb
#
# after: usertime=571.826851 systime=72.906707 mem=1431.5703125 mb
#
# after: usertime=572.327062 systime=72.993267 mem=1431.5703125 mb
#
# after: usertime=572.87597 systime=73.033847 mem=1431.5703125 mb
#
# after: usertime=573.37011 systime=73.129729 mem=1431.5703125 mb
#
# after: usertime=573.871691 systime=73.216985 mem=1431.5703125 mb
#
# after: usertime=574.393273 systime=73.285308 mem=1431.5703125 mb
#
# after: usertime=574.903135 systime=73.362835 mem=1431.5703125 mb
#
# after: usertime=575.450881 systime=73.411968 mem=1431.5703125 mb
#
# after: usertime=575.976838 systime=73.475111 mem=1431.5703125 mb
#
# after: usertime=576.50292 systime=73.537666 mem=1431.5703125 mb
#
# after: usertime=577.014914 systime=73.615465 mem=1431.5703125 mb
#
# after: usertime=577.537794 systime=73.679865 mem=1431.5703125 mb
#
# after: usertime=578.055484 systime=73.759956 mem=1431.5703125 mb
#
# after: usertime=578.570797 systime=73.837659 mem=1431.5703125 mb
#
# after: usertime=579.100538 systime=73.894758 mem=1431.5703125 mb
#
# after: usertime=579.618408 systime=73.9707 mem=1431.5703125 mb
#
# after: usertime=580.155202 systime=74.023919 mem=1431.5703125 mb
#
# after: usertime=580.682835 systime=74.087882 mem=1431.5703125 mb
#
# after: usertime=581.219279 systime=74.140619 mem=1431.5703125 mb
#
# after: usertime=581.7384 systime=74.212111 mem=1431.5703125 mb
#
# after: usertime=582.276864 systime=74.264146 mem=1431.5703125 mb
#
# after: usertime=582.794717 systime=74.334872 mem=1431.5703125 mb
#
# after: usertime=583.341791 systime=74.378265 mem=1431.5703125 mb
#
# after: usertime=583.874614 systime=74.441244 mem=1431.5703125 mb
#
# after: usertime=584.400527 systime=74.503422 mem=1431.5703125 mb
#
# after: usertime=584.933464 systime=74.556316 mem=1431.5703125 mb
#
# after: usertime=585.474833 systime=74.603068 mem=1431.5703125 mb
#
# after: usertime=586.015785 systime=74.649765 mem=1431.5703125 mb
#
# after: usertime=586.546883 systime=74.706431 mem=1431.5703125 mb
#
# after: usertime=587.069255 systime=74.77321 mem=1431.5703125 mb
#
# after: usertime=587.599084 systime=74.834846 mem=1431.5703125 mb
#
# after: usertime=588.108391 systime=74.919881 mem=1431.5703125 mb
#
# after: usertime=588.626771 systime=74.991801 mem=1431.5703125 mb
#
# after: usertime=589.140976 systime=75.067719 mem=1431.5703125 mb
#
# after: usertime=589.685272 systime=75.113728 mem=1431.5703125 mb
#
# after: usertime=590.211651 systime=75.175368 mem=1431.5703125 mb
#
# after: usertime=590.74378 systime=75.232168 mem=1431.5703125 mb
#
# after: usertime=591.269662 systime=75.295904 mem=1431.5703125 mb
#
# after: usertime=591.778424 systime=75.375295 mem=1431.5703125 mb
#
# after: usertime=592.316312 systime=75.429706 mem=1431.5703125 mb
#
# after: usertime=592.826221 systime=75.512365 mem=1431.5703125 mb
#
# after: usertime=593.366255 systime=75.564157 mem=1431.5703125 mb
#
# after: usertime=593.872185 systime=75.647873 mem=1431.5703125 mb
#
# after: usertime=594.40712 systime=75.700499 mem=1431.5703125 mb
#
# after: usertime=594.909149 systime=75.78825 mem=1431.5703125 mb
#
# after: usertime=595.439734 systime=75.847378 mem=1431.5703125 mb
#
# after: usertime=595.996916 systime=75.878679 mem=1431.5703125 mb
#
# after: usertime=596.52532 systime=75.945782 mem=1431.5703125 mb
#
# after: usertime=597.059528 systime=76.001285 mem=1431.5703125 mb
#
# after: usertime=597.547806 systime=76.103712 mem=1431.5703125 mb
#
# after: usertime=598.091217 systime=76.151768 mem=1431.5703125 mb
#
# after: usertime=598.643258 systime=76.190068 mem=1431.5703125 mb
#
# after: usertime=599.164904 systime=76.258838 mem=1431.5703125 mb
#
# after: usertime=599.679703 systime=76.336472 mem=1431.5703125 mb
#
# after: usertime=600.204327 systime=76.404059 mem=1431.5703125 mb
#
# after: usertime=600.742627 systime=76.459564 mem=1431.5703125 mb
#
# after: usertime=601.25918 systime=76.530807 mem=1431.5703125 mb
#
# after: usertime=601.78247 systime=76.596218 mem=1431.5703125 mb
#
# after: usertime=602.324708 systime=76.64249 mem=1431.5703125 mb
#
# after: usertime=602.874991 systime=76.681683 mem=1431.5703125 mb
#
# after: usertime=603.398011 systime=76.7481 mem=1431.5703125 mb
#
# after: usertime=603.941831 systime=76.794055 mem=1431.5703125 mb
#
# after: usertime=604.476153 systime=76.848087 mem=1431.5703125 mb
#
# after: usertime=605.017056 systime=76.903856 mem=1431.5703125 mb
#
# after: usertime=605.541645 systime=76.965727 mem=1431.5703125 mb
#
# after: usertime=606.07929 systime=77.015127 mem=1431.5703125 mb
#
# after: usertime=606.597694 systime=77.084975 mem=1431.5703125 mb
#
# after: usertime=607.120634 systime=77.151381 mem=1431.5703125 mb
#
# after: usertime=607.657765 systime=77.204732 mem=1431.5703125 mb
#
# after: usertime=608.178377 systime=77.275516 mem=1431.5703125 mb
#
# after: usertime=608.707009 systime=77.335894 mem=1431.5703125 mb
#
# after: usertime=609.222001 systime=77.41407 mem=1431.5703125 mb
#
# after: usertime=609.755969 systime=77.472145 mem=1431.5703125 mb
#
# after: usertime=610.289276 systime=77.529164 mem=1431.5703125 mb
#
# after: usertime=610.799727 systime=77.610331 mem=1431.5703125 mb
#
# after: usertime=611.333286 systime=77.665306 mem=1431.5703125 mb
#
# after: usertime=611.855479 systime=77.73103 mem=1431.5703125 mb
#
# after: usertime=612.384107 systime=77.795562 mem=1431.5703125 mb
#
# after: usertime=612.917391 systime=77.851993 mem=1431.5703125 mb
#
# after: usertime=613.417808 systime=77.946222 mem=1431.5703125 mb
#
# after: usertime=613.948571 systime=78.0024 mem=1431.5703125 mb
#
# after: usertime=614.490665 systime=78.050671 mem=1431.5703125 mb
#
# after: usertime=615.037051 systime=78.099035 mem=1431.5703125 mb
#
# after: usertime=615.590005 systime=78.138048 mem=1431.5703125 mb
#
# after: usertime=616.119887 systime=78.196122 mem=1431.5703125 mb
#
# after: usertime=616.637536 systime=78.263867 mem=1431.5703125 mb
#
# after: usertime=617.167202 systime=78.320358 mem=1431.5703125 mb
#
# after: usertime=617.69236 systime=78.391068 mem=1431.5703125 mb
#
# after: usertime=618.238213 systime=78.43528 mem=1431.5703125 mb
#
# after: usertime=618.749285 systime=78.510426 mem=1431.5703125 mb
#
# after: usertime=619.276959 systime=78.569714 mem=1431.5703125 mb
#
# after: usertime=619.799257 systime=78.635 mem=1431.5703125 mb
#
# after: usertime=620.335031 systime=78.692207 mem=1431.5703125 mb
#
# after: usertime=620.881605 systime=78.731388 mem=1431.5703125 mb
#
# after: usertime=621.419243 systime=78.779165 mem=1431.5703125 mb
#
# after: usertime=621.936412 systime=78.85652 mem=1431.5703125 mb
#
# after: usertime=622.434577 systime=78.94637 mem=1431.5703125 mb
#
# after: usertime=622.974228 systime=78.996935 mem=1431.5703125 mb
#
# after: usertime=623.507999 systime=79.048368 mem=1431.5703125 mb
#
# after: usertime=624.016322 systime=79.128745 mem=1431.5703125 mb
#
# after: usertime=624.526547 systime=79.207807 mem=1431.5703125 mb
#
# after: usertime=625.076634 systime=79.246403 mem=1431.5703125 mb
#
# after: usertime=625.613134 systime=79.297607 mem=1431.5703125 mb
#
# after: usertime=626.15603 systime=79.349104 mem=1431.5703125 mb
#
# after: usertime=626.68456 systime=79.410115 mem=1431.5703125 mb
#
# after: usertime=627.216136 systime=79.466908 mem=1431.5703125 mb
#
# after: usertime=627.727333 systime=79.544081 mem=1431.5703125 mb
#
# after: usertime=628.262809 systime=79.59717 mem=1431.5703125 mb
#
# after: usertime=628.770485 systime=79.676946 mem=1431.5703125 mb
#
# after: usertime=629.289801 systime=79.745479 mem=1431.5703125 mb
#
# after: usertime=629.811482 systime=79.810743 mem=1431.5703125 mb
#
# after: usertime=630.345848 systime=79.869904 mem=1431.5703125 mb
#
# after: usertime=630.85547 systime=79.949984 mem=1431.5703125 mb
#
# after: usertime=631.380218 systime=80.014545 mem=1431.5703125 mb
#
# after: usertime=631.895743 systime=80.08818 mem=1431.5703125 mb
#
# after: usertime=632.435164 systime=80.139292 mem=1431.5703125 mb
#
# after: usertime=632.970631 systime=80.191972 mem=1431.5703125 mb
#
# after: usertime=633.498403 systime=80.25381 mem=1431.5703125 mb
#
# after: usertime=634.009836 systime=80.332049 mem=1431.5703125 mb
#
# after: usertime=634.550322 systime=80.386863 mem=1431.5703125 mb
#
# after: usertime=635.096648 systime=80.432636 mem=1431.5703125 mb
#
# after: usertime=635.598741 systime=80.520804 mem=1431.5703125 mb
#
# after: usertime=636.125752 systime=80.584672 mem=1431.5703125 mb
#
# after: usertime=636.674397 systime=80.627691 mem=1431.5703125 mb
#
# after: usertime=637.174791 systime=80.71834 mem=1431.5703125 mb
#
# after: usertime=637.695319 systime=80.788061 mem=1431.5703125 mb
#
# after: usertime=638.204751 systime=80.866045 mem=1431.5703125 mb
#
# after: usertime=638.766725 systime=80.904595 mem=1431.5703125 mb
#
# after: usertime=639.273033 systime=80.987823 mem=1431.5703125 mb
#
# after: usertime=639.788639 systime=81.05986 mem=1431.5703125 mb
#
# after: usertime=640.332734 systime=81.107941 mem=1431.625 mb
#
# after: usertime=640.846228 systime=81.184425 mem=1431.625 mb
#
# after: usertime=641.372754 systime=81.247195 mem=1431.625 mb
#
# after: usertime=641.884908 systime=81.324545 mem=1431.625 mb
#
# after: usertime=642.44034 systime=81.356734 mem=1431.625 mb
#
# after: usertime=642.978826 systime=81.41481 mem=1431.625 mb
#
# after: usertime=643.511123 systime=81.47469 mem=1431.625 mb
#
# after: usertime=644.041506 systime=81.535879 mem=1431.625 mb
#
# after: usertime=644.557108 systime=81.611488 mem=1431.625 mb
#
# after: usertime=645.087646 systime=81.668611 mem=1431.625 mb
#
# after: usertime=645.609973 systime=81.733901 mem=1431.625 mb
#
# after: usertime=646.158024 systime=81.775296 mem=1431.625 mb
#
# after: usertime=646.690482 systime=81.831629 mem=1431.625 mb
#
# after: usertime=647.223276 systime=81.89721 mem=1431.625 mb
#
# after: usertime=647.769851 systime=81.940537 mem=1431.625 mb
#
# after: usertime=648.300767 systime=81.997661 mem=1431.625 mb
#
# after: usertime=648.801178 systime=82.08629 mem=1431.625 mb
#
# after: usertime=649.305452 systime=82.173241 mem=1431.625 mb
#
# after: usertime=649.847084 systime=82.222048 mem=1431.625 mb
#
# after: usertime=650.378117 systime=82.283788 mem=1431.625 mb
#
# after: usertime=650.907597 systime=82.342797 mem=1431.625 mb
#
# after: usertime=651.431713 systime=82.416016 mem=1431.625 mb
#
# after: usertime=651.931116 systime=82.506483 mem=1431.625 mb
#
# after: usertime=652.459664 systime=82.567959 mem=1431.625 mb
#
# after: usertime=652.975718 systime=82.641091 mem=1431.625 mb
#
# after: usertime=653.517026 systime=82.687325 mem=1431.625 mb
#
# after: usertime=654.051945 systime=82.739469 mem=1431.625 mb
#
# after: usertime=654.556925 systime=82.824023 mem=1431.625 mb
#
# after: usertime=655.10386 systime=82.865897 mem=1431.625 mb
#
# after: usertime=655.623883 systime=82.939583 mem=1431.625 mb
#
# after: usertime=656.151816 systime=83.002999 mem=1431.625 mb
#
# after: usertime=656.690364 systime=83.061136 mem=1431.625 mb
#
# after: usertime=657.193016 systime=83.147465 mem=1431.625 mb
#
# after: usertime=657.722866 systime=83.208637 mem=1431.625 mb
#
# after: usertime=658.235877 systime=83.286506 mem=1431.625 mb
#
# after: usertime=658.735631 systime=83.374535 mem=1431.625 mb
#
# after: usertime=659.288649 systime=83.409425 mem=1431.625 mb
#
# after: usertime=659.797907 systime=83.496538 mem=1431.625 mb
#
# after: usertime=660.328036 systime=83.555729 mem=1431.625 mb
#
# after: usertime=660.864044 systime=83.610494 mem=1431.625 mb
#
# after: usertime=661.403673 systime=83.66163 mem=1431.625 mb
#
# after: usertime=661.922635 systime=83.731146 mem=1431.625 mb
#
# after: usertime=662.421259 systime=83.820536 mem=1431.625 mb
#
# after: usertime=662.939062 systime=83.888822 mem=1431.625 mb
#
# after: usertime=663.45446 systime=83.958355 mem=1431.625 mb
#
# after: usertime=663.987154 systime=84.020872 mem=1431.625 mb
#
# after: usertime=664.507553 systime=84.093055 mem=1431.625 mb
#
# after: usertime=665.006013 systime=84.187545 mem=1431.625 mb
#
# after: usertime=665.532351 systime=84.25029 mem=1431.625 mb
#
# after: usertime=666.064124 systime=84.310156 mem=1431.625 mb
#
# after: usertime=666.581573 systime=84.382535 mem=1431.625 mb
#
# after: usertime=667.08625 systime=84.46602 mem=1431.625 mb
#
# after: usertime=667.611877 systime=84.528159 mem=1431.625 mb
#
# after: usertime=668.158667 systime=84.576633 mem=1431.625 mb
#
# after: usertime=668.689008 systime=84.6373 mem=1431.625 mb
#
# after: usertime=669.222558 systime=84.695319 mem=1431.625 mb
#
# after: usertime=669.750109 systime=84.755116 mem=1431.625 mb
#
# after: usertime=670.286403 systime=84.809397 mem=1431.625 mb
#
# after: usertime=670.810807 systime=84.872882 mem=1431.625 mb
#
# after: usertime=671.345095 systime=84.928411 mem=1431.625 mb
#
# after: usertime=671.888601 systime=84.973318 mem=1431.625 mb
#
# after: usertime=672.394268 systime=85.060547 mem=1431.625 mb
#
# after: usertime=672.919753 systime=85.12727 mem=1431.625 mb
#
# after: usertime=673.437215 systime=85.201717 mem=1431.625 mb
#
# after: usertime=673.996868 systime=85.230817 mem=1431.625 mb
#
# after: usertime=674.53259 systime=85.285025 mem=1431.625 mb
#
# after: usertime=675.050013 systime=85.35782 mem=1431.625 mb
#
# after: usertime=675.570684 systime=85.425532 mem=1431.625 mb
#
# after: usertime=676.101384 systime=85.482674 mem=1431.625 mb
#
# after: usertime=676.654679 systime=85.52783 mem=1431.625 mb
#
# after: usertime=677.179374 systime=85.592949 mem=1431.625 mb
#
# after: usertime=677.696025 systime=85.665741 mem=1431.625 mb
#
# after: usertime=678.220958 systime=85.73338 mem=1431.625 mb
#
# after: usertime=678.717464 systime=85.827064 mem=1431.625 mb
#
# after: usertime=679.249925 systime=85.884946 mem=1431.625 mb
#
# after: usertime=679.762613 systime=85.962262 mem=1431.625 mb
#
# after: usertime=680.259343 systime=86.052967 mem=1431.625 mb
#
# after: usertime=680.783978 systime=86.127238 mem=1431.65234375 mb
#
# after: usertime=681.301299 systime=86.196448 mem=1431.65234375 mb
#
# after: usertime=681.840087 systime=86.249494 mem=1431.65234375 mb
#
# after: usertime=682.372112 systime=86.313944 mem=1431.65625 mb
#
# after: usertime=682.916069 systime=86.363088 mem=1431.65625 mb
#
# after: usertime=683.421554 systime=86.450248 mem=1431.65625 mb
#
# after: usertime=683.952571 systime=86.50945 mem=1431.65625 mb
#
# after: usertime=684.495083 systime=86.556768 mem=1431.65625 mb
#
# after: usertime=685.005371 systime=86.645566 mem=1431.67578125 mb
#
# after: usertime=685.51321 systime=86.727384 mem=1431.67578125 mb
#
# after: usertime=686.01834 systime=86.812476 mem=1431.67578125 mb
#
# after: usertime=686.525666 systime=86.893244 mem=1431.67578125 mb
#
# after: usertime=687.061277 systime=86.950493 mem=1431.67578125 mb
#
# after: usertime=687.58393 systime=87.015823 mem=1431.67578125 mb
#
# after: usertime=688.122379 systime=87.067279 mem=1431.67578125 mb
#
# after: usertime=688.631905 systime=87.146773 mem=1431.67578125 mb
#
# after: usertime=689.176012 systime=87.199928 mem=1431.67578125 mb
#
# after: usertime=689.714761 systime=87.248937 mem=1431.67578125 mb
#
# after: usertime=690.262467 systime=87.292409 mem=1431.67578125 mb
#
# after: usertime=690.80601 systime=87.340424 mem=1431.67578125 mb
#
# after: usertime=691.3287 systime=87.406746 mem=1431.67578125 mb
#
# after: usertime=691.878684 systime=87.448394 mem=1431.67578125 mb
#
# after: usertime=692.418083 systime=87.496875 mem=1431.67578125 mb
#
# after: usertime=692.956855 systime=87.547861 mem=1431.67578125 mb
#
# after: usertime=693.505083 systime=87.594923 mem=1431.67578125 mb
#
# after: usertime=694.033175 systime=87.656815 mem=1431.67578125 mb
#
# after: usertime=694.560171 systime=87.719084 mem=1431.67578125 mb
#
# after: usertime=695.087722 systime=87.783444 mem=1431.67578125 mb
#
# after: usertime=695.647602 systime=87.813029 mem=1431.67578125 mb
#
# after: usertime=696.173651 systime=87.878273 mem=1431.67578125 mb
#
# after: usertime=696.683925 systime=87.957387 mem=1431.67578125 mb
#
# after: usertime=697.219709 systime=88.012124 mem=1431.67578125 mb
#
# after: usertime=697.790047 systime=88.041088 mem=1431.67578125 mb
#
# after: usertime=698.293572 systime=88.126488 mem=1431.67578125 mb
#
# after: usertime=698.833573 systime=88.177156 mem=1431.67578125 mb
#
# after: usertime=699.376203 systime=88.225027 mem=1431.67578125 mb
#
# after: usertime=699.928561 systime=88.261912 mem=1431.67578125 mb
#
# after: usertime=700.457042 systime=88.32187 mem=1431.67578125 mb
#
# after: usertime=700.981824 systime=88.386955 mem=1431.67578125 mb
#
# after: usertime=701.512098 systime=88.448613 mem=1431.67578125 mb
#
# after: usertime=702.050062 systime=88.509732 mem=1431.67578125 mb
#
# after: usertime=702.590209 systime=88.559389 mem=1431.67578125 mb
#
# after: usertime=703.119488 systime=88.619928 mem=1431.67578125 mb
#
# after: usertime=703.643713 systime=88.686487 mem=1431.67578125 mb
#
# after: usertime=704.182167 systime=88.738437 mem=1431.67578125 mb
#
# after: usertime=704.704547 systime=88.807303 mem=1431.67578125 mb
#
# after: usertime=705.260229 systime=88.843065 mem=1431.67578125 mb
#
# after: usertime=705.767954 systime=88.921307 mem=1431.67578125 mb
#
# after: usertime=706.307714 systime=88.974518 mem=1431.67578125 mb
#
# after: usertime=706.859327 systime=89.014396 mem=1431.67578125 mb
#
# after: usertime=707.370785 systime=89.091083 mem=1431.67578125 mb
#
# after: usertime=707.902426 systime=89.152434 mem=1431.67578125 mb
#
# after: usertime=708.443009 systime=89.200603 mem=1431.67578125 mb
#
# after: usertime=708.976891 systime=89.25404 mem=1431.67578125 mb
#
# after: usertime=709.512111 systime=89.305647 mem=1431.67578125 mb
#
# after: usertime=710.024776 systime=89.38043 mem=1431.67578125 mb
#
# after: usertime=710.564274 systime=89.435631 mem=1431.67578125 mb
#
# after: usertime=711.078745 systime=89.512156 mem=1431.67578125 mb
#
# after: usertime=711.596617 systime=89.584537 mem=1431.67578125 mb
#
# after: usertime=712.14127 systime=89.626055 mem=1431.67578125 mb
#
# after: usertime=712.691756 systime=89.663737 mem=1431.67578125 mb
#
# after: usertime=713.233396 systime=89.711554 mem=1431.67578125 mb
#
# after: usertime=713.77729 systime=89.756548 mem=1431.67578125 mb
#
# after: usertime=714.306008 systime=89.817532 mem=1431.67578125 mb
#
# after: usertime=714.854985 systime=89.866247 mem=1431.67578125 mb
#
# after: usertime=715.367392 systime=89.942541 mem=1431.67578125 mb
#
# after: usertime=715.901865 systime=89.996572 mem=1431.67578125 mb
#
# after: usertime=716.449804 systime=90.036991 mem=1431.67578125 mb
#
# after: usertime=716.979258 systime=90.100056 mem=1431.67578125 mb
#
# after: usertime=717.526462 systime=90.142438 mem=1431.67578125 mb
#
# after: usertime=718.060056 systime=90.198415 mem=1431.67578125 mb
#
# after: usertime=718.584668 systime=90.259911 mem=1431.67578125 mb
#
# after: usertime=719.115255 systime=90.329809 mem=1431.67578125 mb
#
# after: usertime=719.654534 systime=90.382436 mem=1431.67578125 mb
#
# after: usertime=720.161713 systime=90.465725 mem=1431.67578125 mb
#
# after: usertime=720.686425 systime=90.529284 mem=1431.67578125 mb
#
# after: usertime=721.201427 systime=90.603871 mem=1431.67578125 mb
#
# after: usertime=721.760837 systime=90.636562 mem=1431.67578125 mb
#
# after: usertime=722.296579 systime=90.690263 mem=1431.67578125 mb
#
# after: usertime=722.840149 systime=90.734747 mem=1431.67578125 mb
#
# after: usertime=723.361989 systime=90.809169 mem=1431.67578125 mb
#
# after: usertime=723.903142 systime=90.856902 mem=1431.67578125 mb
#
# after: usertime=724.427882 systime=90.920975 mem=1431.67578125 mb
#
# after: usertime=724.965229 systime=90.971817 mem=1431.67578125 mb
#
# after: usertime=725.474388 systime=91.051805 mem=1431.67578125 mb
#
# after: usertime=726.001394 systime=91.116675 mem=1431.67578125 mb
#
# after: usertime=726.527188 systime=91.177308 mem=1431.67578125 mb
#
# after: usertime=727.023706 systime=91.26897 mem=1431.67578125 mb
#
# after: usertime=727.563849 systime=91.325784 mem=1431.67578125 mb
#
# after: usertime=728.106605 systime=91.372178 mem=1431.67578125 mb
#
# after: usertime=728.631418 systime=91.436756 mem=1431.67578125 mb
#
# after: usertime=729.151711 systime=91.507925 mem=1431.67578125 mb
#
# after: usertime=729.685838 systime=91.563471 mem=1431.67578125 mb
#
# after: usertime=730.18677 systime=91.653654 mem=1431.67578125 mb
#
# after: usertime=730.71833 systime=91.711936 mem=1431.67578125 mb
#
# after: usertime=731.255569 systime=91.761753 mem=1431.67578125 mb
#
# after: usertime=731.781992 systime=91.829592 mem=1431.67578125 mb
#
# after: usertime=732.300843 systime=91.905144 mem=1431.67578125 mb
#
# after: usertime=732.814289 systime=91.983622 mem=1431.67578125 mb
#
# after: usertime=733.339997 systime=92.045749 mem=1431.67578125 mb
#
# after: usertime=733.880325 systime=92.093889 mem=1431.67578125 mb
#
# after: usertime=734.420598 systime=92.142008 mem=1431.67578125 mb
#
# after: usertime=734.950842 systime=92.204209 mem=1431.67578125 mb
#
# after: usertime=735.490191 systime=92.25375 mem=1431.67578125 mb
#
# after: usertime=736.037209 systime=92.304254 mem=1431.67578125 mb
#
# after: usertime=736.56261 systime=92.371439 mem=1431.67578125 mb
#
# after: usertime=737.072329 systime=92.448423 mem=1431.67578125 mb
#
# after: usertime=737.592085 systime=92.517985 mem=1431.67578125 mb
#
# after: usertime=738.113293 systime=92.586721 mem=1431.67578125 mb
#
# after: usertime=738.659738 systime=92.631562 mem=1431.67578125 mb
#
# after: usertime=739.184215 systime=92.697123 mem=1431.67578125 mb
#
# after: usertime=739.708358 systime=92.759581 mem=1431.67578125 mb
#
# after: usertime=740.260923 systime=92.804663 mem=1431.67578125 mb
#
# after: usertime=740.785791 systime=92.871285 mem=1431.67578125 mb
#
# after: usertime=741.296551 systime=92.94941 mem=1431.67578125 mb
#
# after: usertime=741.826392 systime=93.010524 mem=1431.67578125 mb
#
# after: usertime=742.340468 systime=93.085479 mem=1431.67578125 mb
#
# after: usertime=742.874618 systime=93.142027 mem=1431.67578125 mb
#
# after: usertime=743.392971 systime=93.216009 mem=1431.67578125 mb
#
# after: usertime=743.927872 systime=93.27114 mem=1431.67578125 mb
#
# after: usertime=744.482444 systime=93.314944 mem=1431.67578125 mb
#
# after: usertime=744.989301 systime=93.398719 mem=1431.67578125 mb
#
# after: usertime=745.505458 systime=93.471414 mem=1431.67578125 mb
#
# after: usertime=746.052203 systime=93.515258 mem=1431.67578125 mb
#
# after: usertime=746.561848 systime=93.597861 mem=1431.67578125 mb
#
# after: usertime=747.089632 systime=93.6623 mem=1431.67578125 mb
#
# after: usertime=747.603633 systime=93.736235 mem=1431.67578125 mb
#
# after: usertime=748.122579 systime=93.807219 mem=1431.67578125 mb
#
# after: usertime=748.647418 systime=93.879468 mem=1431.67578125 mb
#
# after: usertime=749.170517 systime=93.945354 mem=1431.67578125 mb
#
# after: usertime=749.686644 systime=94.019043 mem=1431.67578125 mb
#
# after: usertime=750.223258 systime=94.07439 mem=1431.67578125 mb
#
# after: usertime=750.760156 systime=94.124142 mem=1431.67578125 mb
#
# after: usertime=751.280353 systime=94.192736 mem=1431.67578125 mb
#
# after: usertime=751.800089 systime=94.260761 mem=1431.67578125 mb
#
# after: usertime=752.307219 systime=94.339451 mem=1431.67578125 mb
#
# after: usertime=752.83775 systime=94.411888 mem=1431.67578125 mb
#
# after: usertime=753.355597 systime=94.483769 mem=1431.67578125 mb
#
# after: usertime=753.861714 systime=94.565404 mem=1431.67578125 mb
#
# after: usertime=754.393523 systime=94.621672 mem=1431.67578125 mb
#
# after: usertime=754.897021 systime=94.704001 mem=1431.67578125 mb
#
# after: usertime=755.430531 systime=94.757936 mem=1431.67578125 mb
#
# after: usertime=755.955974 systime=94.820048 mem=1431.67578125 mb
#
# after: usertime=756.444333 systime=94.91884 mem=1431.67578125 mb
#
# after: usertime=756.983596 systime=94.975546 mem=1431.67578125 mb
#
# after: usertime=757.516445 systime=95.030935 mem=1431.67578125 mb
#
# after: usertime=758.043111 systime=95.090142 mem=1431.67578125 mb
#
# after: usertime=758.581543 systime=95.141109 mem=1431.67578125 mb
#
# after: usertime=759.093981 systime=95.21688 mem=1431.67578125 mb
#
# after: usertime=759.586691 systime=95.313175 mem=1431.67578125 mb
#
# after: usertime=760.11336 systime=95.373904 mem=1431.67578125 mb
#
# after: usertime=760.634772 systime=95.43908 mem=1431.67578125 mb
#
# after: usertime=761.160705 systime=95.50889 mem=1431.67578125 mb
#
# after: usertime=761.714453 systime=95.54494 mem=1431.67578125 mb
#
# after: usertime=762.259085 systime=95.5967 mem=1431.67578125 mb
#
# after: usertime=762.77939 systime=95.67909 mem=1431.67578125 mb
#
# after: usertime=763.290113 systime=95.760263 mem=1431.67578125 mb
#
# after: usertime=763.809081 systime=95.830253 mem=1431.67578125 mb
#
# after: usertime=764.348497 systime=95.880335 mem=1431.67578125 mb
#
# after: usertime=764.861606 systime=95.953643 mem=1431.67578125 mb
#
# after: usertime=765.392773 systime=96.018009 mem=1431.67578125 mb
#
# after: usertime=765.890944 systime=96.109371 mem=1431.67578125 mb
#
# after: usertime=766.411739 systime=96.175494 mem=1431.67578125 mb
#
# after: usertime=766.943915 systime=96.231808 mem=1431.67578125 mb
#
# after: usertime=767.461489 systime=96.303658 mem=1431.67578125 mb
#
# after: usertime=767.981839 systime=96.374319 mem=1431.67578125 mb
#
# after: usertime=768.516943 systime=96.430503 mem=1431.67578125 mb
#
# after: usertime=769.03436 systime=96.50131 mem=1431.67578125 mb
#
# after: usertime=769.559553 systime=96.573588 mem=1431.67578125 mb
#
# after: usertime=770.214076 systime=96.663569 mem=1431.67578125 mb
#
# after: usertime=770.74554 systime=96.728469 mem=1431.67578125 mb
#
# after: usertime=771.276616 systime=96.789735 mem=1431.67578125 mb
#
# after: usertime=771.816353 systime=96.838336 mem=1431.67578125 mb
#
# after: usertime=772.341173 systime=96.903955 mem=1431.67578125 mb
#
# ...
# after: usertime=11586.638684 systime=1418.701933 mem=1436.71875 mb
#
# after: usertime=11587.161551 systime=1418.76837 mem=1436.71875 mb
#
# after: usertime=11587.677768 systime=1418.841699 mem=1436.71875 mb
#
# after: usertime=11588.221077 systime=1418.884002 mem=1436.71875 mb
#
# after: usertime=11588.769727 systime=1418.922128 mem=1436.71875 mb
#
# after: usertime=11589.310171 systime=1418.978575 mem=1436.71875 mb
#
# after: usertime=11589.816744 systime=1419.061693 mem=1436.71875 mb
#
# after: usertime=11590.34654 systime=1419.120362 mem=1436.71875 mb
#
# after: usertime=11590.871311 systime=1419.186905 mem=1436.71875 mb
#
# after: usertime=11591.399662 systime=1419.249966 mem=1436.71875 mb
#
# after: usertime=11591.926586 systime=1419.309201 mem=1436.71875 mb
#
# after: usertime=11592.435339 systime=1419.386052 mem=1436.71875 mb
#
# after: usertime=11592.986557 systime=1419.423447 mem=1436.71875 mb
#
# after: usertime=11593.548531 systime=1419.456282 mem=1436.71875 mb
#
# after: usertime=11594.06412 systime=1419.532409 mem=1436.71875 mb
#
# after: usertime=11594.590761 systime=1419.594612 mem=1436.71875 mb
#
# after: usertime=11595.104781 systime=1419.670151 mem=1436.71875 mb
#
# after: usertime=11595.640331 systime=1419.720645 mem=1436.71875 mb
#
# after: usertime=11596.16312 systime=1419.787991 mem=1436.71875 mb
#
# after: usertime=11596.654519 systime=1419.884656 mem=1436.71875 mb
#
# after: usertime=11597.181908 systime=1419.945778 mem=1436.71875 mb
#
# after: usertime=11597.720581 systime=1420.003576 mem=1436.71875 mb
#
# after: usertime=11598.231127 systime=1420.081565 mem=1436.71875 mb
#
# after: usertime=11598.770774 systime=1420.130603 mem=1436.71875 mb
#
# after: usertime=11599.314946 systime=1420.175238 mem=1436.71875 mb
#
# after: usertime=11599.842095 systime=1420.238675 mem=1436.71875 mb
#
# after: usertime=11600.371521 systime=1420.29717 mem=1436.71875 mb
#
# after: usertime=11600.893014 systime=1420.36488 mem=1436.71875 mb
#
# after: usertime=11601.440816 systime=1420.404732 mem=1436.71875 mb
#
# after: usertime=11601.987455 systime=1420.452021 mem=1436.71875 mb
#
# after: usertime=11602.515185 systime=1420.513176 mem=1436.71875 mb
#
# after: usertime=11603.03137 systime=1420.590415 mem=1436.71875 mb
#
# after: usertime=11603.553964 systime=1420.655385 mem=1436.71875 mb
#
# after: usertime=11604.094465 systime=1420.70231 mem=1436.71875 mb
#
# after: usertime=11604.614206 systime=1420.771501 mem=1436.71875 mb
#
# after: usertime=11605.126068 systime=1420.849129 mem=1436.71875 mb
#
# after: usertime=11605.664001 systime=1420.898084 mem=1436.71875 mb
#
# after: usertime=11606.176836 systime=1420.97557 mem=1436.71875 mb
#
# after: usertime=11606.693029 systime=1421.048635 mem=1436.71875 mb
#
# after: usertime=11607.208787 systime=1421.122692 mem=1436.71875 mb
#
# after: usertime=11607.742046 systime=1421.177348 mem=1436.71875 mb
#
# after: usertime=11608.240164 systime=1421.270005 mem=1436.71875 mb
#
# after: usertime=11608.753273 systime=1421.344783 mem=1436.71875 mb
#
# after: usertime=11609.302322 systime=1421.391053 mem=1436.71875 mb
#
# after: usertime=11609.816362 systime=1421.467117 mem=1436.71875 mb
#
# after: usertime=11610.353752 systime=1421.528806 mem=1436.71875 mb
#
# after: usertime=11610.891568 systime=1421.577098 mem=1436.71875 mb
#
# after: usertime=11611.419326 systime=1421.637607 mem=1436.71875 mb
#
# after: usertime=11611.947354 systime=1421.69998 mem=1436.71875 mb
#
# after: usertime=11612.466151 systime=1421.768666 mem=1436.71875 mb
#
# after: usertime=11613.014042 systime=1421.811665 mem=1436.71875 mb
#
# after: usertime=11613.525578 systime=1421.890948 mem=1436.71875 mb
#
# after: usertime=11614.056257 systime=1421.946199 mem=1436.71875 mb
#
# after: usertime=11614.57889 systime=1422.019784 mem=1436.71875 mb
#
# after: usertime=11615.113565 systime=1422.072784 mem=1436.71875 mb
#
# after: usertime=11615.649151 systime=1422.126546 mem=1436.71875 mb
#
# after: usertime=11616.181161 systime=1422.183924 mem=1436.71875 mb
#
# after: usertime=11616.727408 systime=1422.228678 mem=1436.71875 mb
#
# after: usertime=11617.265906 systime=1422.280712 mem=1436.71875 mb
#
# after: usertime=11617.792764 systime=1422.342157 mem=1436.71875 mb
#
# after: usertime=11618.335252 systime=1422.385801 mem=1436.71875 mb
#
# after: usertime=11618.859787 systime=1422.456885 mem=1436.71875 mb
#
# after: usertime=11619.388665 systime=1422.528628 mem=1436.71875 mb
#
# after: usertime=11619.954699 systime=1422.556219 mem=1436.71875 mb
#
# after: usertime=11620.481505 systime=1422.615439 mem=1436.71875 mb
#
# after: usertime=11621.003376 systime=1422.682276 mem=1436.71875 mb
#
# after: usertime=11621.530526 systime=1422.739843 mem=1436.71875 mb
#
# after: usertime=11622.077382 systime=1422.784934 mem=1436.71875 mb
#
# after: usertime=11622.588589 systime=1422.861958 mem=1436.71875 mb
#
# after: usertime=11623.104432 systime=1422.942941 mem=1436.71875 mb
#
# after: usertime=11623.607204 systime=1423.028723 mem=1436.71875 mb
#
# after: usertime=11624.128352 systime=1423.095995 mem=1436.71875 mb
#
# after: usertime=11624.655009 systime=1423.158199 mem=1436.71875 mb
#
# after: usertime=11625.181997 systime=1423.223968 mem=1436.71875 mb
#
# after: usertime=11625.706809 systime=1423.28856 mem=1436.71875 mb
#
# after: usertime=11626.221098 systime=1423.363086 mem=1436.71875 mb
#
# after: usertime=11626.748301 systime=1423.426397 mem=1436.71875 mb
#
# after: usertime=11627.297234 systime=1423.47879 mem=1436.71875 mb
#
# after: usertime=11627.803675 systime=1423.562019 mem=1436.71875 mb
#
# after: usertime=11628.32353 systime=1423.63775 mem=1436.71875 mb
#
# after: usertime=11628.844583 systime=1423.707363 mem=1436.71875 mb
#
# after: usertime=11629.370266 systime=1423.773622 mem=1436.71875 mb
#
# after: usertime=11629.932106 systime=1423.802267 mem=1436.71875 mb
#
# after: usertime=11630.450331 systime=1423.874669 mem=1436.71875 mb
#
# after: usertime=11630.976448 systime=1423.935634 mem=1436.71875 mb
#
# after: usertime=11631.521122 systime=1423.988425 mem=1436.71875 mb
#
# after: usertime=11632.069519 systime=1424.03044 mem=1436.71875 mb
#
# after: usertime=11632.606712 systime=1424.082837 mem=1436.71875 mb
#
# after: usertime=11633.115363 systime=1424.162812 mem=1436.71875 mb
#
# after: usertime=11633.600429 systime=1424.267454 mem=1436.71875 mb
#
# after: usertime=11634.119157 systime=1424.33835 mem=1436.71875 mb
#
# after: usertime=11634.658558 systime=1424.388665 mem=1436.71875 mb
#
# after: usertime=11635.202302 systime=1424.434681 mem=1436.71875 mb
#
# after: usertime=11635.741451 systime=1424.48967 mem=1436.71875 mb
#
# after: usertime=11636.255104 systime=1424.564514 mem=1436.71875 mb
#
# after: usertime=11636.80067 systime=1424.605533 mem=1436.71875 mb
#
# after: usertime=11637.321988 systime=1424.673221 mem=1436.71875 mb
#
# after: usertime=11637.824548 systime=1424.762113 mem=1436.71875 mb
#
# after: usertime=11638.336072 systime=1424.837744 mem=1436.71875 mb
#
# after: usertime=11638.862404 systime=1424.901348 mem=1436.71875 mb
#
# after: usertime=11639.402648 systime=1424.948899 mem=1436.71875 mb
#
# after: usertime=11639.924749 systime=1425.024383 mem=1436.71875 mb
#
# after: usertime=11640.452803 systime=1425.087676 mem=1436.71875 mb
#
# after: usertime=11640.960794 systime=1425.171618 mem=1436.71875 mb
#
# after: usertime=11641.500936 systime=1425.219544 mem=1436.71875 mb
#
# after: usertime=11642.024309 systime=1425.284214 mem=1436.71875 mb
#
# after: usertime=11642.549681 systime=1425.349658 mem=1436.71875 mb
#
# after: usertime=11643.09511 systime=1425.394177 mem=1436.71875 mb
#
# after: usertime=11643.641629 systime=1425.440009 mem=1436.71875 mb
#
# after: usertime=11644.181376 systime=1425.499373 mem=1436.71875 mb
#
# after: usertime=11644.711767 systime=1425.560466 mem=1436.71875 mb
#
# after: usertime=11645.25182 systime=1425.611899 mem=1436.71875 mb
#
# after: usertime=11645.785126 systime=1425.669698 mem=1436.71875 mb
#
# after: usertime=11646.307201 systime=1425.736828 mem=1436.71875 mb
#
# after: usertime=11646.822862 systime=1425.81218 mem=1436.71875 mb
#
# after: usertime=11647.344004 systime=1425.878802 mem=1436.71875 mb
#
# after: usertime=11647.862892 systime=1425.945148 mem=1436.71875 mb
#
# after: usertime=11648.389213 systime=1426.016974 mem=1436.71875 mb
#
# after: usertime=11648.893909 systime=1426.100385 mem=1436.71875 mb
#
# after: usertime=11649.440064 systime=1426.144081 mem=1436.71875 mb
#
# after: usertime=11649.964192 systime=1426.211068 mem=1436.71875 mb
#
# after: usertime=11650.498423 systime=1426.268323 mem=1436.71875 mb
#
# after: usertime=11651.042158 systime=1426.311724 mem=1436.71875 mb
#
# after: usertime=11651.557044 systime=1426.385017 mem=1436.71875 mb
#
# after: usertime=11652.086133 systime=1426.44047 mem=1436.71875 mb
#
# after: usertime=11652.621088 systime=1426.500553 mem=1436.71875 mb
#
# after: usertime=11653.116477 systime=1426.594184 mem=1436.71875 mb
#
# after: usertime=11653.652844 systime=1426.644777 mem=1436.71875 mb
#
# after: usertime=11654.194268 systime=1426.692599 mem=1436.71875 mb
#
# after: usertime=11654.740071 systime=1426.770067 mem=1436.71875 mb
#
# after: usertime=11655.280015 systime=1426.819792 mem=1436.71875 mb
#
# after: usertime=11655.80514 systime=1426.882981 mem=1436.71875 mb
#
# after: usertime=11656.331527 systime=1426.943323 mem=1436.71875 mb
#
# after: usertime=11656.85312 systime=1427.017049 mem=1436.71875 mb
#
# after: usertime=11657.379507 systime=1427.07739 mem=1436.71875 mb
#
# after: usertime=11657.91863 systime=1427.126887 mem=1436.71875 mb
#
# after: usertime=11658.449097 systime=1427.186683 mem=1436.71875 mb
#
# after: usertime=11658.979823 systime=1427.244292 mem=1436.71875 mb
#
# after: usertime=11659.50304 systime=1427.313258 mem=1436.71875 mb
#
# after: usertime=11660.025508 systime=1427.38043 mem=1436.71875 mb
#
# after: usertime=11660.547438 systime=1427.445319 mem=1436.71875 mb
#
# after: usertime=11661.088561 systime=1427.503806 mem=1436.71875 mb
#
# after: usertime=11661.617769 systime=1427.56854 mem=1436.71875 mb
#
# after: usertime=11662.123893 systime=1427.652911 mem=1436.71875 mb
#
# after: usertime=11662.636676 systime=1427.731435 mem=1436.71875 mb
#
# after: usertime=11663.168848 systime=1427.786219 mem=1436.71875 mb
#
# after: usertime=11663.715282 systime=1427.830868 mem=1436.71875 mb
#
# after: usertime=11664.23731 systime=1427.899293 mem=1436.71875 mb
#
# after: usertime=11664.787456 systime=1427.936429 mem=1436.71875 mb
#
# after: usertime=11665.319466 systime=1427.997854 mem=1436.71875 mb
#
# after: usertime=11665.848623 systime=1428.061403 mem=1436.71875 mb
#
# after: usertime=11666.378167 systime=1428.122654 mem=1436.71875 mb
#
# after: usertime=11666.900754 systime=1428.187489 mem=1436.71875 mb
#
# after: usertime=11667.415478 systime=1428.262465 mem=1436.71875 mb
#
# after: usertime=11667.945693 systime=1428.32158 mem=1436.71875 mb
#
# after: usertime=11668.4765 systime=1428.377765 mem=1436.71875 mb
#
# after: usertime=11668.998079 systime=1428.440914 mem=1436.71875 mb
#
# after: usertime=11669.530984 systime=1428.504406 mem=1436.8125 mb
#
# after: usertime=11670.206043 systime=1428.579537 mem=1436.8203125 mb
#
# after: usertime=11670.731401 systime=1428.643801 mem=1436.8203125 mb
#
# after: usertime=11671.256064 systime=1428.711376 mem=1436.8203125 mb
#
# after: usertime=11671.797558 systime=1428.763642 mem=1436.8203125 mb
#
# after: usertime=11672.314968 systime=1428.837768 mem=1436.8203125 mb
#
# after: usertime=11672.844245 systime=1428.900815 mem=1436.8203125 mb
#
# after: usertime=11673.373019 systime=1428.96628 mem=1436.8203125 mb
#
# after: usertime=11673.915286 systime=1429.014856 mem=1436.8203125 mb
#
# after: usertime=11674.437489 systime=1429.083563 mem=1436.8203125 mb
#
# after: usertime=11674.97567 systime=1429.137643 mem=1436.8203125 mb
#
# after: usertime=11675.512975 systime=1429.189658 mem=1436.8203125 mb
#
# after: usertime=11676.042952 systime=1429.249266 mem=1436.8203125 mb
#
# after: usertime=11676.579136 systime=1429.302451 mem=1436.8203125 mb
#
# after: usertime=11677.128847 systime=1429.348673 mem=1436.8203125 mb
#
# after: usertime=11677.677935 systime=1429.388421 mem=1436.8203125 mb
#
# after: usertime=11678.2159 systime=1429.441822 mem=1436.8203125 mb
#
# after: usertime=11678.74694 systime=1429.500644 mem=1436.8203125 mb
#
# after: usertime=11679.272839 systime=1429.565885 mem=1436.8203125 mb
#
# after: usertime=11679.792823 systime=1429.633538 mem=1436.8203125 mb
#
# after: usertime=11680.357393 systime=1429.658206 mem=1436.8203125 mb
#
# after: usertime=11680.868646 systime=1429.735103 mem=1436.8203125 mb
#
# after: usertime=11681.391381 systime=1429.80897 mem=1436.8203125 mb
#
# after: usertime=11681.938269 systime=1429.852495 mem=1436.8203125 mb
#
# after: usertime=11682.443944 systime=1429.937983 mem=1436.8203125 mb
#
# after: usertime=11682.926563 systime=1430.045717 mem=1436.8203125 mb
#
# after: usertime=11683.436729 systime=1430.125356 mem=1436.8203125 mb
#
# after: usertime=11683.966211 systime=1430.184903 mem=1436.8203125 mb
#
# after: usertime=11684.504843 systime=1430.233817 mem=1436.8203125 mb
#
# after: usertime=11685.01369 systime=1430.313689 mem=1436.8203125 mb
#
# after: usertime=11685.555967 systime=1430.364222 mem=1436.8203125 mb
#
# after: usertime=11686.090902 systime=1430.422085 mem=1436.8203125 mb
#
# after: usertime=11686.584014 systime=1430.519746 mem=1436.8203125 mb
#
# after: usertime=11687.132501 systime=1430.563862 mem=1436.8203125 mb
#
# after: usertime=11687.675336 systime=1430.608721 mem=1436.8203125 mb
#
# after: usertime=11688.197953 systime=1430.676045 mem=1436.8203125 mb
#
# after: usertime=11688.717265 systime=1430.743488 mem=1436.8203125 mb
#
# after: usertime=11689.243508 systime=1430.806163 mem=1436.8203125 mb
#
# after: usertime=11689.768608 systime=1430.874442 mem=1436.8203125 mb
#
# after: usertime=11690.27805 systime=1430.956867 mem=1436.8203125 mb
#
# after: usertime=11690.826887 systime=1431.00246 mem=1436.8203125 mb
#
# after: usertime=11691.346765 systime=1431.070622 mem=1436.8203125 mb
#
# after: usertime=11691.87163 systime=1431.135609 mem=1436.8203125 mb
#
# after: usertime=11692.411244 systime=1431.188035 mem=1436.8203125 mb
#
# after: usertime=11692.931051 systime=1431.259585 mem=1436.8203125 mb
